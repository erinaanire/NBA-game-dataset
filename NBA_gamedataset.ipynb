# %%
NBA games data

# %%
### 1. Import the libraries

# %%
import pandas as pd

# %%
### 2. Load the data in `games.csv` as a DataFrame called `games`

###Save the csv file under the same directory as the notebook if not typing the full path.

# %%
games = pd.read_csv("/Users/emrik/Downloads/archive/games.csv")

# %%
### 3. Look at the first 5 rows of the DataFrame

# %%
games.head(5)
# Out:
#     GAME_DATE   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0  2020-12-19  12000047            Final    1610612753       1610612766
# 1  2020-12-19  12000048            Final    1610612764       1610612765
# 2  2020-12-19  12000049            Final    1610612763       1610612737
# 3  2020-12-18  12000039            Final    1610612754       1610612755
# 4  2020-12-18  12000040            Final    1610612761       1610612748
#
#    SEASON  TEAM_ID_home  POINTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2020    1610612753          120        0.433        0.792  ...        23
# 1    2020    1610612764           99        0.427        0.625  ...        24
# 2    2020    1610612763          116        0.400        0.744  ...        21
# 3    2020    1610612754          107        0.371        0.692  ...        19
# 4    2020    1610612761          105        0.380        0.737  ...        27
#
#    REB_home  TEAM_ID_away  POINTS_away  FG_PCT_away  FT_PCT_away  \
# 0        50    1610612766          117        0.444        0.864
# 1        45    1610612765           96        0.402        0.647
# 2        43    1610612737          117        0.422        0.837
# 3        45    1610612755          113        0.533        0.629
# 4        37    1610612748          117        0.534        0.741
#
#    FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0         0.439        21        52               1
# 1         0.326        18        51               1
# 2         0.297        24        47               0
# 3         0.355        23        48               0
# 4         0.514        30        51               0
#
# [5 rows x 21 columns]

# %%
### 4. Look at the columns of the DataFrame

# %%
games.columns
# Out:
# Index(['GAME_DATE', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'POINTS_home',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'TEAM_ID_away', 'POINTS_away', 'FG_PCT_away', 'FT_PCT_away',
#        'FG3_PCT_away', 'AST_away', 'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
### 5. Reassign `games` as its subset of the columns 'GAME_DATE', 'GAME_STATUS_TEXT', 'TEAM_ID_home', 'TEAM_ID_away', 'POINTS_home', 'POINTS_away', 'HOME_TEAM_WINS'

##We'll only keep some columns about the games

# %%
games=games[['GAME_DATE','GAME_STATUS_TEXT','TEAM_ID_home','TEAM_ID_away','POINTS_home','POINTS_away','HOME_TEAM_WINS']]

# %%
games
# Out:
#         GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0      2020-12-19            Final    1610612753    1610612766          120
# 1      2020-12-19            Final    1610612764    1610612765           99
# 2      2020-12-19            Final    1610612763    1610612737          116
# 3      2020-12-18            Final    1610612754    1610612755          107
# 4      2020-12-18            Final    1610612761    1610612748          105
# ...           ...              ...           ...           ...          ...
# 23416  2014-10-06            Final    1610612737    1610612740           93
# 23417  2014-10-06            Final    1610612741    1610612764           81
# 23418  2014-10-06            Final    1610612747    1610612743           98
# 23419  2014-10-05            Final    1610612761    1610612758           99
# 23420  2014-10-04            Final    1610612748    1610612740           86
#
#        POINTS_away  HOME_TEAM_WINS
# 0              117               1
# 1               96               1
# 2              117               0
# 3              113               0
# 4              117               0
# ...            ...             ...
# 23416           87               1
# 23417           85               0
# 23418           95               1
# 23419           94               1
# 23420           98               0
#
# [23421 rows x 7 columns]

# %%
### 6. Look at the new `games` DataFrame's first 5 rows, and info summary

# %%
games.head()
# Out:
#     GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0  2020-12-19            Final    1610612753    1610612766          120
# 1  2020-12-19            Final    1610612764    1610612765           99
# 2  2020-12-19            Final    1610612763    1610612737          116
# 3  2020-12-18            Final    1610612754    1610612755          107
# 4  2020-12-18            Final    1610612761    1610612748          105
#
#    POINTS_away  HOME_TEAM_WINS
# 0          117               1
# 1           96               1
# 2          117               0
# 3          113               0
# 4          117               0

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23421 entries, 0 to 23420
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE         23421 non-null  object
#  1   GAME_STATUS_TEXT  23421 non-null  object
#  2   TEAM_ID_home      23421 non-null  int64
#  3   TEAM_ID_away      23421 non-null  int64
#  4   POINTS_home       23421 non-null  int64
#  5   POINTS_away       23421 non-null  int64
#  6   HOME_TEAM_WINS    23421 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1.3+ MB

# %%
### 7. Convert `GAME_DATE` to a `datetime` dtype

# %%
games['GAME_DATE']=pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0       2020-12-19
# 1       2020-12-19
# 2       2020-12-19
# 3       2020-12-18
# 4       2020-12-18
#            ...
# 23416   2014-10-06
# 23417   2014-10-06
# 23418   2014-10-06
# 23419   2014-10-05
# 23420   2014-10-04
# Name: GAME_DATE, Length: 23421, dtype: datetime64[ns]

# %%
### 8. Convert `GAME_STATUS_TEXT` to a `string` dtype

# %%
games['GAME_STATUS_TEXT']=games['GAME_STATUS_TEXT'].astype('string')

# %%
games['GAME_STATUS_TEXT']
# Out:
# 0        Final
# 1        Final
# 2        Final
# 3        Final
# 4        Final
#          ...
# 23416    Final
# 23417    Final
# 23418    Final
# 23419    Final
# 23420    Final
# Name: GAME_STATUS_TEXT, Length: 23421, dtype: string

# %%
### 9. Look at the info summary of the DataFrame to verify the changes

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23421 entries, 0 to 23420
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE         23421 non-null  datetime64[ns]
#  1   GAME_STATUS_TEXT  23421 non-null  string
#  2   TEAM_ID_home      23421 non-null  int64
#  3   TEAM_ID_away      23421 non-null  int64
#  4   POINTS_home       23421 non-null  int64
#  5   POINTS_away       23421 non-null  int64
#  6   HOME_TEAM_WINS    23421 non-null  int64
# dtypes: datetime64[ns](1), int64(5), string(1)
# memory usage: 1.3 MB

# %%
### 10. Load the data in `teams.csv` as a DataFrame called `teams`, and look at its first 5 rows, and its columns

# %%
teams = pd.read_csv("/Users/emrik/Downloads/archive/teams.csv")

# %%
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# 0     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 2       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 3  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 4       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %%
teams.columns
# Out:
# Index(['LEAGUE_ID', 'TEAM_ID', 'MIN_YEAR', 'MAX_YEAR', 'ABBREVIATION',
#        'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER',
#        'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION'],
#       dtype='object')

# %%
### 11. Reassign `teams` as a subset of its columns 'TEAM_ID', 'CITY', 'NICKNAME', and look at its first 5 rows and info summary

##We'll only keep some columns about the teams

# %%
teams = teams[['TEAM_ID', 'CITY', 'NICKNAME']]

# %%
teams.head()
# Out:
#       TEAM_ID         CITY   NICKNAME
# 0  1610612737      Atlanta      Hawks
# 1  1610612738       Boston    Celtics
# 2  1610612740  New Orleans   Pelicans
# 3  1610612741      Chicago      Bulls
# 4  1610612742       Dallas  Mavericks

# %%
### 12. Convert both columns `CITY` and `NICKNAME` to a `string` dtype

# %%
##teams['CITY'] = teams['CITY'].astype('string')

# %%
##teams['NICKNAME']=teams['NICKNAME'].astype('string')

# %%
teams = teams.astype({'CITY': 'string', 'NICKNAME': 'string'})

# %%
teams
# Out:
#        TEAM_ID           CITY       NICKNAME
# 0   1610612737        Atlanta          Hawks
# 1   1610612738         Boston        Celtics
# 2   1610612740    New Orleans       Pelicans
# 3   1610612741        Chicago          Bulls
# 4   1610612742         Dallas      Mavericks
# 5   1610612743         Denver        Nuggets
# 6   1610612745        Houston        Rockets
# 7   1610612746    Los Angeles       Clippers
# 8   1610612747    Los Angeles         Lakers
# 9   1610612748          Miami           Heat
# 10  1610612749      Milwaukee          Bucks
# 11  1610612750      Minnesota   Timberwolves
# 12  1610612751       Brooklyn           Nets
# 13  1610612752       New York         Knicks
# 14  1610612753        Orlando          Magic
# 15  1610612754        Indiana         Pacers
# 16  1610612755   Philadelphia          76ers
# 17  1610612756        Phoenix           Suns
# 18  1610612757       Portland  Trail Blazers
# 19  1610612758     Sacramento          Kings
# 20  1610612759    San Antonio          Spurs
# 21  1610612760  Oklahoma City        Thunder
# 22  1610612761        Toronto        Raptors
# 23  1610612762           Utah           Jazz
# 24  1610612763        Memphis      Grizzlies
# 25  1610612764     Washington        Wizards
# 26  1610612765        Detroit        Pistons
# 27  1610612766      Charlotte        Hornets
# 28  1610612739      Cleveland      Cavaliers
# 29  1610612744   Golden State       Warriors

# %%
### 13. Verify the changes with the `dtypes` attribute

# %%
teams.dtypes
# Out:
# TEAM_ID      int64
# CITY        string
# NICKNAME    string
# dtype: object

# %%
### 14. Print out the first two rows of `games` and `teams`, how can we combine them?

# %%
games.head(2)
# Out:
#    GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-19            Final    1610612764    1610612765           99
#
#    POINTS_away  HOME_TEAM_WINS
# 0          117               1
# 1           96               1

# %%
teams.head(2)
# Out:
#       TEAM_ID     CITY NICKNAME
# 0  1610612737  Atlanta    Hawks
# 1  1610612738   Boston  Celtics

# %%
### 15. Merge (inner) `games` and `teams` based on 'TEAM_ID_home' and 'TEAM_ID', call the merged DataFrame `games_with_home_team`

# %%
games_with_home_team=pd.merge(games, teams, left_on='TEAM_ID_home', right_on='TEAM_ID', how='inner')

# %%
### 16. Print out the first 5 rows of the new DataFrame

# %%
games_with_home_team.head(5)
# Out:
#    GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
# 2 2020-08-24            Final    1610612753    1610612749          106
# 3 2020-08-22            Final    1610612753    1610612749          107
# 4 2020-08-13            Final    1610612753    1610612740          133
#
#    POINTS_away  HOME_TEAM_WINS     TEAM_ID     CITY NICKNAME
# 0          117               1  1610612753  Orlando    Magic
# 1          123               0  1610612753  Orlando    Magic
# 2          121               0  1610612753  Orlando    Magic
# 3          121               0  1610612753  Orlando    Magic
# 4          127               1  1610612753  Orlando    Magic

# %%
### 17. Rename the column `CITY` as 'city_home', `NICKNAME` as 'nickname_home'

# %%
games_with_home_team = games_with_home_team.rename(columns={'CITY':'city_home','NICKNAME':'nickname_home'})

# %%
games_with_home_team
# Out:
#        GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0     2020-12-19            Final    1610612753    1610612766          120
# 1     2020-12-17            Final    1610612753    1610612766          115
# 2     2020-08-24            Final    1610612753    1610612749          106
# 3     2020-08-22            Final    1610612753    1610612749          107
# 4     2020-08-13            Final    1610612753    1610612740          133
# ...          ...              ...           ...           ...          ...
# 23416 2014-11-05            Final    1610612744    1610612746          121
# 23417 2014-11-01            Final    1610612744    1610612747          127
# 23418 2014-10-24            Final    1610612744    1610612743          119
# 23419 2014-10-21            Final    1610612744    1610612746          125
# 23420 2014-10-16            Final    1610612744    1610612743          104
#
#        POINTS_away  HOME_TEAM_WINS     TEAM_ID     city_home nickname_home
# 0              117               1  1610612753       Orlando         Magic
# 1              123               0  1610612753       Orlando         Magic
# 2              121               0  1610612753       Orlando         Magic
# 3              121               0  1610612753       Orlando         Magic
# 4              127               1  1610612753       Orlando         Magic
# ...            ...             ...         ...           ...           ...
# 23416          104               1  1610612744  Golden State      Warriors
# 23417          104               1  1610612744  Golden State      Warriors
# 23418          112               1  1610612744  Golden State      Warriors
# 23419          107               1  1610612744  Golden State      Warriors
# 23420          101               1  1610612744  Golden State      Warriors
#
# [23421 rows x 10 columns]

# %%
### 18. Merge (inner) `games_with_home_team` and `teams` based on 'TEAM_ID_away' and 'TEAM_ID', call the merged DataFrame `games_with_both_teams`

# %%
games_with_both_teams = pd.merge(games_with_home_team,teams,left_on ='TEAM_ID_away',right_on = 'TEAM_ID',how = 'inner')

# %%
games_with_both_teams.head(2)
# Out:
#    GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
#
#    POINTS_away  HOME_TEAM_WINS   TEAM_ID_x city_home nickname_home  \
# 0          117               1  1610612753   Orlando         Magic
# 1          123               0  1610612753   Orlando         Magic
#
#     TEAM_ID_y       CITY NICKNAME
# 0  1610612766  Charlotte  Hornets
# 1  1610612766  Charlotte  Hornets

# %%
### 20. Rename the column `CITY` as 'city_away', `NICKNAME` as 'nickname_away'

# %%
games_with_both_teams=games_with_both_teams.rename(columns={'CITY':'city_away','NICKNAME':'nickname_away'})

# %%
games_with_both_teams.head()
# Out:
#    GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
# 2 2014-03-28            Final    1610612753    1610612766          110
# 3 2014-01-17            Final    1610612753    1610612766          101
# 4 2013-02-19            Final    1610612753    1610612766           92
#
#    POINTS_away  HOME_TEAM_WINS   TEAM_ID_x city_home nickname_home  \
# 0          117               1  1610612753   Orlando         Magic
# 1          123               0  1610612753   Orlando         Magic
# 2          105               1  1610612753   Orlando         Magic
# 3          111               0  1610612753   Orlando         Magic
# 4          105               0  1610612753   Orlando         Magic
#
#     TEAM_ID_y  city_away nickname_away
# 0  1610612766  Charlotte       Hornets
# 1  1610612766  Charlotte       Hornets
# 2  1610612766  Charlotte       Hornets
# 3  1610612766  Charlotte       Hornets
# 4  1610612766  Charlotte       Hornets

# %%
### 21. Print out the first 5 rows of the new DataFrame

# %%
games_with_both_teams.head()
# Out:
#    GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
# 2 2014-03-28            Final    1610612753    1610612766          110
# 3 2014-01-17            Final    1610612753    1610612766          101
# 4 2013-02-19            Final    1610612753    1610612766           92
#
#    POINTS_away  HOME_TEAM_WINS   TEAM_ID_x city_home nickname_home  \
# 0          117               1  1610612753   Orlando         Magic
# 1          123               0  1610612753   Orlando         Magic
# 2          105               1  1610612753   Orlando         Magic
# 3          111               0  1610612753   Orlando         Magic
# 4          105               0  1610612753   Orlando         Magic
#
#     TEAM_ID_y  city_away nickname_away
# 0  1610612766  Charlotte       Hornets
# 1  1610612766  Charlotte       Hornets
# 2  1610612766  Charlotte       Hornets
# 3  1610612766  Charlotte       Hornets
# 4  1610612766  Charlotte       Hornets

# %%
### 22. Make a copy of `games_with_both_teams` and assign it as `games`

# %%
games=games_with_both_teams.copy()

# %%
games
# Out:
#        GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0     2020-12-19            Final    1610612753    1610612766          120
# 1     2020-12-17            Final    1610612753    1610612766          115
# 2     2014-03-28            Final    1610612753    1610612766          110
# 3     2014-01-17            Final    1610612753    1610612766          101
# 4     2013-02-19            Final    1610612753    1610612766           92
# ...          ...              ...           ...           ...          ...
# 23416 2018-11-26            Final    1610612744    1610612753          116
# 23417 2017-11-13            Final    1610612744    1610612753          110
# 23418 2017-03-16            Final    1610612744    1610612753          122
# 23419 2016-03-07            Final    1610612744    1610612753          119
# 23420 2014-12-02            Final    1610612744    1610612753           98
#
#        POINTS_away  HOME_TEAM_WINS   TEAM_ID_x     city_home nickname_home  \
# 0              117               1  1610612753       Orlando         Magic
# 1              123               0  1610612753       Orlando         Magic
# 2              105               1  1610612753       Orlando         Magic
# 3              111               0  1610612753       Orlando         Magic
# 4              105               0  1610612753       Orlando         Magic
# ...            ...             ...         ...           ...           ...
# 23416          110               1  1610612744  Golden State      Warriors
# 23417          100               1  1610612744  Golden State      Warriors
# 23418           92               1  1610612744  Golden State      Warriors
# 23419          113               1  1610612744  Golden State      Warriors
# 23420           97               1  1610612744  Golden State      Warriors
#
#         TEAM_ID_y  city_away nickname_away
# 0      1610612766  Charlotte       Hornets
# 1      1610612766  Charlotte       Hornets
# 2      1610612766  Charlotte       Hornets
# 3      1610612766  Charlotte       Hornets
# 4      1610612766  Charlotte       Hornets
# ...           ...        ...           ...
# 23416  1610612753    Orlando         Magic
# 23417  1610612753    Orlando         Magic
# 23418  1610612753    Orlando         Magic
# 23419  1610612753    Orlando         Magic
# 23420  1610612753    Orlando         Magic
#
# [23421 rows x 13 columns]

# %%
### 23. Change the column names in `games` to all lowercase

# %%
games.columns = games.columns.str.lower()

# %%
### 24. Print out the columns of `games` to verify the changes

# %%
games.columns
# Out:
# Index(['game_date', 'game_status_text', 'team_id_home', 'team_id_away',
#        'points_home', 'points_away', 'home_team_wins', 'team_id_x',
#        'city_home', 'nickname_home', 'team_id_y', 'city_away',
#        'nickname_away'],
#       dtype='object')

# %%
### 25. Print out the columns of `games_with_both_teams` to verify that the original DataFrame wasn't impacted by the copy

# %%
games_with_both_teams.columns
# Out:
# Index(['GAME_DATE', 'GAME_STATUS_TEXT', 'TEAM_ID_home', 'TEAM_ID_away',
#        'POINTS_home', 'POINTS_away', 'HOME_TEAM_WINS', 'TEAM_ID_x',
#        'city_home', 'nickname_home', 'TEAM_ID_y', 'city_away',
#        'nickname_away'],
#       dtype='object')

# %%
### 26. Check the dimensionality  of `games`

# %%
games.shape
# Out:
# (23421, 13)

# %%
### 27. Export `games` as a csv file called 'games_transformed.csv', and open the csv file to look at it

# %%
games.to_csv('games_transformed.csv',index=False)

# %%
### 28. Select all the columns of 'number' dtypes from `games`

# %%
games.select_dtypes(include='number')
# Out:
#        team_id_home  team_id_away  points_home  points_away  home_team_wins  \
# 0        1610612753    1610612766          120          117               1
# 1        1610612753    1610612766          115          123               0
# 2        1610612753    1610612766          110          105               1
# 3        1610612753    1610612766          101          111               0
# 4        1610612753    1610612766           92          105               0
# ...             ...           ...          ...          ...             ...
# 23416    1610612744    1610612753          116          110               1
# 23417    1610612744    1610612753          110          100               1
# 23418    1610612744    1610612753          122           92               1
# 23419    1610612744    1610612753          119          113               1
# 23420    1610612744    1610612753           98           97               1
#
#         team_id_x   team_id_y
# 0      1610612753  1610612766
# 1      1610612753  1610612766
# 2      1610612753  1610612766
# 3      1610612753  1610612766
# 4      1610612753  1610612766
# ...           ...         ...
# 23416  1610612744  1610612753
# 23417  1610612744  1610612753
# 23418  1610612744  1610612753
# 23419  1610612744  1610612753
# 23420  1610612744  1610612753
#
# [23421 rows x 7 columns]

# %%
### 29. Select all the columns NOT of 'number' dtypes from `games`

# %%
games.select_dtypes(exclude='number')
# Out:
#        game_date game_status_text     city_home nickname_home  city_away  \
# 0     2020-12-19            Final       Orlando         Magic  Charlotte
# 1     2020-12-17            Final       Orlando         Magic  Charlotte
# 2     2014-03-28            Final       Orlando         Magic  Charlotte
# 3     2014-01-17            Final       Orlando         Magic  Charlotte
# 4     2013-02-19            Final       Orlando         Magic  Charlotte
# ...          ...              ...           ...           ...        ...
# 23416 2018-11-26            Final  Golden State      Warriors    Orlando
# 23417 2017-11-13            Final  Golden State      Warriors    Orlando
# 23418 2017-03-16            Final  Golden State      Warriors    Orlando
# 23419 2016-03-07            Final  Golden State      Warriors    Orlando
# 23420 2014-12-02            Final  Golden State      Warriors    Orlando
#
#       nickname_away
# 0           Hornets
# 1           Hornets
# 2           Hornets
# 3           Hornets
# 4           Hornets
# ...             ...
# 23416         Magic
# 23417         Magic
# 23418         Magic
# 23419         Magic
# 23420         Magic
#
# [23421 rows x 6 columns]

# %%
### 30. Print out the first 5 rows of `games` as a reference

# %%
games.head()
# Out:
#    game_date game_status_text  team_id_home  team_id_away  points_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
# 2 2014-03-28            Final    1610612753    1610612766          110
# 3 2014-01-17            Final    1610612753    1610612766          101
# 4 2013-02-19            Final    1610612753    1610612766           92
#
#    points_away  home_team_wins   team_id_x city_home nickname_home  \
# 0          117               1  1610612753   Orlando         Magic
# 1          123               0  1610612753   Orlando         Magic
# 2          105               1  1610612753   Orlando         Magic
# 3          111               0  1610612753   Orlando         Magic
# 4          105               0  1610612753   Orlando         Magic
#
#     team_id_y  city_away nickname_away
# 0  1610612766  Charlotte       Hornets
# 1  1610612766  Charlotte       Hornets
# 2  1610612766  Charlotte       Hornets
# 3  1610612766  Charlotte       Hornets
# 4  1610612766  Charlotte       Hornets

# %%
### 31. Select the row with label 0

# %%
games.loc[0]
# Out:
# game_date           2020-12-19 00:00:00
# game_status_text                  Final
# team_id_home                 1610612753
# team_id_away                 1610612766
# points_home                         120
# points_away                         117
# home_team_wins                        1
# team_id_x                    1610612753
# city_home                       Orlando
# nickname_home                     Magic
# team_id_y                    1610612766
# city_away                     Charlotte
# nickname_away                   Hornets
# Name: 0, dtype: object

# %%
### 32. Select the row with integer position 0

# %%
games.iloc[0]
# Out:
# game_date           2020-12-19 00:00:00
# game_status_text                  Final
# team_id_home                 1610612753
# team_id_away                 1610612766
# points_home                         120
# points_away                         117
# home_team_wins                        1
# team_id_x                    1610612753
# city_home                       Orlando
# nickname_home                     Magic
# team_id_y                    1610612766
# city_away                     Charlotte
# nickname_away                   Hornets
# Name: 0, dtype: object

# %%
### 33. Set the column `game_date` as the index of DataFrame `games`

# %%
games=games.set_index('game_date')

# %%
games
# Out:
#            game_status_text  team_id_home  team_id_away  points_home  \
# game_date
# 2020-12-19            Final    1610612753    1610612766          120
# 2020-12-17            Final    1610612753    1610612766          115
# 2014-03-28            Final    1610612753    1610612766          110
# 2014-01-17            Final    1610612753    1610612766          101
# 2013-02-19            Final    1610612753    1610612766           92
# ...                     ...           ...           ...          ...
# 2018-11-26            Final    1610612744    1610612753          116
# 2017-11-13            Final    1610612744    1610612753          110
# 2017-03-16            Final    1610612744    1610612753          122
# 2016-03-07            Final    1610612744    1610612753          119
# 2014-12-02            Final    1610612744    1610612753           98
#
#             points_away  home_team_wins   team_id_x     city_home  \
# game_date
# 2020-12-19          117               1  1610612753       Orlando
# 2020-12-17          123               0  1610612753       Orlando
# 2014-03-28          105               1  1610612753       Orlando
# 2014-01-17          111               0  1610612753       Orlando
# 2013-02-19          105               0  1610612753       Orlando
# ...                 ...             ...         ...           ...
# 2018-11-26          110               1  1610612744  Golden State
# 2017-11-13          100               1  1610612744  Golden State
# 2017-03-16           92               1  1610612744  Golden State
# 2016-03-07          113               1  1610612744  Golden State
# 2014-12-02           97               1  1610612744  Golden State
#
#            nickname_home   team_id_y  city_away nickname_away
# game_date
# 2020-12-19         Magic  1610612766  Charlotte       Hornets
# 2020-12-17         Magic  1610612766  Charlotte       Hornets
# 2014-03-28         Magic  1610612766  Charlotte       Hornets
# 2014-01-17         Magic  1610612766  Charlotte       Hornets
# 2013-02-19         Magic  1610612766  Charlotte       Hornets
# ...                  ...         ...        ...           ...
# 2018-11-26      Warriors  1610612753    Orlando         Magic
# 2017-11-13      Warriors  1610612753    Orlando         Magic
# 2017-03-16      Warriors  1610612753    Orlando         Magic
# 2016-03-07      Warriors  1610612753    Orlando         Magic
# 2014-12-02      Warriors  1610612753    Orlando         Magic
#
# [23421 rows x 12 columns]

# %%
### 34. Print out the index of `games` to verify the changes

# %%
games.index
# Out:
# DatetimeIndex(['2020-12-19', '2020-12-17', '2014-03-28', '2014-01-17',
#                '2013-02-19', '2013-01-18', '2012-04-25', '2012-01-17',
#                '2011-04-01', '2011-02-27',
#                ...
#                '2007-12-03', '2007-01-10', '2006-03-01', '2004-12-10',
#                '2004-03-17', '2018-11-26', '2017-11-13', '2017-03-16',
#                '2016-03-07', '2014-12-02'],
#               dtype='datetime64[ns]', name='game_date', length=23421, freq=None)

# %%
### 35. Select the rows with label '2020-12-18'

# %%
games.loc['2020-12-18']
# Out:
#            game_status_text  team_id_home  team_id_away  points_home  \
# game_date
# 2020-12-18            Final    1610612740    1610612749          127
# 2020-12-18            Final    1610612738    1610612751           89
# 2020-12-18            Final    1610612756    1610612747          113
# 2020-12-18            Final    1610612743    1610612757          129
# 2020-12-18            Final    1610612761    1610612748          105
# 2020-12-18            Final    1610612754    1610612755          107
# 2020-12-18            Final    1610612760    1610612741          103
# 2020-12-18            Final    1610612752    1610612739          119
#
#             points_away  home_team_wins   team_id_x      city_home  \
# game_date
# 2020-12-18          113               1  1610612740    New Orleans
# 2020-12-18          113               0  1610612738         Boston
# 2020-12-18          114               0  1610612756        Phoenix
# 2020-12-18           96               1  1610612743         Denver
# 2020-12-18          117               0  1610612761        Toronto
# 2020-12-18          113               0  1610612754        Indiana
# 2020-12-18          105               0  1610612760  Oklahoma City
# 2020-12-18           83               1  1610612752       New York
#
#            nickname_home   team_id_y     city_away  nickname_away
# game_date
# 2020-12-18      Pelicans  1610612749     Milwaukee          Bucks
# 2020-12-18       Celtics  1610612751      Brooklyn           Nets
# 2020-12-18          Suns  1610612747   Los Angeles         Lakers
# 2020-12-18       Nuggets  1610612757      Portland  Trail Blazers
# 2020-12-18       Raptors  1610612748         Miami           Heat
# 2020-12-18        Pacers  1610612755  Philadelphia          76ers
# 2020-12-18       Thunder  1610612741       Chicago          Bulls
# 2020-12-18        Knicks  1610612739     Cleveland      Cavaliers

# %%
### 36. Select the rows with labels from '2020-12-18' to '2020-12-19'

# %%
games.loc['2020-12-18':'2020-12-19']
# Out:
#            game_status_text  team_id_home  team_id_away  points_home  \
# game_date
# 2020-12-19            Final    1610612753    1610612766          120
# 2020-12-18            Final    1610612740    1610612749          127
# 2020-12-18            Final    1610612738    1610612751           89
# 2020-12-18            Final    1610612756    1610612747          113
# 2020-12-18            Final    1610612743    1610612757          129
# 2020-12-19            Final    1610612764    1610612765           99
# 2020-12-19            Final    1610612763    1610612737          116
# 2020-12-18            Final    1610612761    1610612748          105
# 2020-12-18            Final    1610612754    1610612755          107
# 2020-12-18            Final    1610612760    1610612741          103
# 2020-12-18            Final    1610612752    1610612739          119
#
#             points_away  home_team_wins   team_id_x      city_home  \
# game_date
# 2020-12-19          117               1  1610612753        Orlando
# 2020-12-18          113               1  1610612740    New Orleans
# 2020-12-18          113               0  1610612738         Boston
# 2020-12-18          114               0  1610612756        Phoenix
# 2020-12-18           96               1  1610612743         Denver
# 2020-12-19           96               1  1610612764     Washington
# 2020-12-19          117               0  1610612763        Memphis
# 2020-12-18          117               0  1610612761        Toronto
# 2020-12-18          113               0  1610612754        Indiana
# 2020-12-18          105               0  1610612760  Oklahoma City
# 2020-12-18           83               1  1610612752       New York
#
#            nickname_home   team_id_y     city_away  nickname_away
# game_date
# 2020-12-19         Magic  1610612766     Charlotte        Hornets
# 2020-12-18      Pelicans  1610612749     Milwaukee          Bucks
# 2020-12-18       Celtics  1610612751      Brooklyn           Nets
# 2020-12-18          Suns  1610612747   Los Angeles         Lakers
# 2020-12-18       Nuggets  1610612757      Portland  Trail Blazers
# 2020-12-19       Wizards  1610612765       Detroit        Pistons
# 2020-12-19     Grizzlies  1610612737       Atlanta          Hawks
# 2020-12-18       Raptors  1610612748         Miami           Heat
# 2020-12-18        Pacers  1610612755  Philadelphia          76ers
# 2020-12-18       Thunder  1610612741       Chicago          Bulls
# 2020-12-18        Knicks  1610612739     Cleveland      Cavaliers

# %%
### 37. Select the rows with `points_home` greater than 150

# %%
games[games['points_home']>150]
# Out:
#            game_status_text  team_id_home  team_id_away  points_home  \
# game_date
# 2010-03-16            Final    1610612756    1610612750          152
# 2020-08-25            Final    1610612746    1610612742          154
# 2006-12-27            Final    1610612752    1610612765          151
# 2019-11-30            Final    1610612745    1610612737          158
# 2008-03-16            Final    1610612743    1610612760          168
# 2019-01-10            Final    1610612759    1610612760          154
# 2020-01-28            Final    1610612749    1610612764          151
# 2020-01-26            Final    1610612737    1610612764          152
# 2019-03-01            Final    1610612737    1610612741          161
# 2019-10-30            Final    1610612764    1610612745          158
# 2006-12-07            Final    1610612751    1610612756          157
# 2008-04-06            Final    1610612760    1610612743          151
#
#             points_away  home_team_wins   team_id_x      city_home  \
# game_date
# 2010-03-16          114               1  1610612756        Phoenix
# 2020-08-25          111               1  1610612746    Los Angeles
# 2006-12-27          145               1  1610612752       New York
# 2019-11-30          111               1  1610612745        Houston
# 2008-03-16          116               1  1610612743         Denver
# 2019-01-10          147               1  1610612759    San Antonio
# 2020-01-28          131               1  1610612749      Milwaukee
# 2020-01-26          133               1  1610612737        Atlanta
# 2019-03-01          168               0  1610612737        Atlanta
# 2019-10-30          159               0  1610612764     Washington
# 2006-12-07          161               0  1610612751       Brooklyn
# 2008-04-06          147               1  1610612760  Oklahoma City
#
#            nickname_home   team_id_y      city_away nickname_away
# game_date
# 2010-03-16          Suns  1610612750      Minnesota  Timberwolves
# 2020-08-25      Clippers  1610612742         Dallas     Mavericks
# 2006-12-27        Knicks  1610612765        Detroit       Pistons
# 2019-11-30       Rockets  1610612737        Atlanta         Hawks
# 2008-03-16       Nuggets  1610612760  Oklahoma City       Thunder
# 2019-01-10         Spurs  1610612760  Oklahoma City       Thunder
# 2020-01-28         Bucks  1610612764     Washington       Wizards
# 2020-01-26         Hawks  1610612764     Washington       Wizards
# 2019-03-01         Hawks  1610612741        Chicago         Bulls
# 2019-10-30       Wizards  1610612745        Houston       Rockets
# 2006-12-07          Nets  1610612756        Phoenix          Suns
# 2008-04-06       Thunder  1610612743         Denver       Nuggets

# %%
### 39. Select the rows with `points_home` greater than 150, and `home_team_wins` not being 1

# %%
games[(games['points_home']>150)&(games['home_team_wins']!=1)]
# Out:
#            game_status_text  team_id_home  team_id_away  points_home  \
# game_date
# 2019-03-01            Final    1610612737    1610612741          161
# 2019-10-30            Final    1610612764    1610612745          158
# 2006-12-07            Final    1610612751    1610612756          157
#
#             points_away  home_team_wins   team_id_x   city_home nickname_home  \
# game_date
# 2019-03-01          168               0  1610612737     Atlanta         Hawks
# 2019-10-30          159               0  1610612764  Washington       Wizards
# 2006-12-07          161               0  1610612751    Brooklyn          Nets
#
#              team_id_y city_away nickname_away
# game_date
# 2019-03-01  1610612741   Chicago         Bulls
# 2019-10-30  1610612745   Houston       Rockets
# 2006-12-07  1610612756   Phoenix          Suns

# %%
### 40. Select the rows with `points_home` greater than 150, and `home_team_wins` not being 1, as well as the columns `home_team_wins` and `points_home`

# %%
games.loc[(games['points_home']>150)&(games['home_team_wins']!=1),['home_team_wins','points_home']]
# Out:
#             home_team_wins  points_home
# game_date
# 2019-03-01               0          161
# 2019-10-30               0          158
# 2006-12-07               0          157

# %%
### 41. Reset the index of `games` back to default and verify the changes

# %%
games=games.reset_index()

# %%
games.head(2)
# Out:
#    game_date game_status_text  team_id_home  team_id_away  points_home  \
# 0 2020-12-19            Final    1610612753    1610612766          120
# 1 2020-12-17            Final    1610612753    1610612766          115
#
#    points_away  home_team_wins   team_id_x city_home nickname_home  \
# 0          117               1  1610612753   Orlando         Magic
# 1          123               0  1610612753   Orlando         Magic
#
#     team_id_y  city_away nickname_away
# 0  1610612766  Charlotte       Hornets
# 1  1610612766  Charlotte       Hornets

# %%
### 42. Add a new column called `points_total`, as the sum of columns `points_home` and `points_away`

# %%
games['points_total'] = games['points_home'] + games['points_away']

# %%
### 43. Verify the changes by printing out the three columns `points_home`, `points_away`, `points_total`

# %%
games[['points_home', 'points_away', 'points_total']]
# Out:
#        points_home  points_away  points_total
# 0              120          117           237
# 1              115          123           238
# 2              110          105           215
# 3              101          111           212
# 4               92          105           197
# ...            ...          ...           ...
# 23416          116          110           226
# 23417          110          100           210
# 23418          122           92           214
# 23419          119          113           232
# 23420           98           97           195
#
# [23421 rows x 3 columns]

# %%
### 44. Print out the 3 rows with the largest `points_total` using the `nlargest` method

# %%
games.nlargest(n=3, columns='points_total')
# Out:
#        game_date game_status_text  team_id_home  team_id_away  points_home  \
# 15391 2019-03-01            Final    1610612737    1610612741          161
# 16895 2006-12-07            Final    1610612751    1610612756          157
# 15572 2019-10-30            Final    1610612764    1610612745          158
#
#        points_away  home_team_wins   team_id_x   city_home nickname_home  \
# 15391          168               0  1610612737     Atlanta         Hawks
# 16895          161               0  1610612751    Brooklyn          Nets
# 15572          159               0  1610612764  Washington       Wizards
#
#         team_id_y city_away nickname_away  points_total
# 15391  1610612741   Chicago         Bulls           329
# 16895  1610612756   Phoenix          Suns           318
# 15572  1610612745   Houston       Rockets           317

# %%
### 45. Sort the DataFrame `games` by its `points_total` column in ascending order

# %%
games=games.sort_values(by='points_total')

# %%
### 46. Print out the last 3 rows of the sorted DataFrame

# %%
games.tail(3)
# Out:
#        game_date game_status_text  team_id_home  team_id_away  points_home  \
# 15572 2019-10-30            Final    1610612764    1610612745          158
# 16895 2006-12-07            Final    1610612751    1610612756          157
# 15391 2019-03-01            Final    1610612737    1610612741          161
#
#        points_away  home_team_wins   team_id_x   city_home nickname_home  \
# 15572          159               0  1610612764  Washington       Wizards
# 16895          161               0  1610612751    Brooklyn          Nets
# 15391          168               0  1610612737     Atlanta         Hawks
#
#         team_id_y city_away nickname_away  points_total
# 15572  1610612745   Houston       Rockets           317
# 16895  1610612756   Phoenix          Suns           318
# 15391  1610612741   Chicago         Bulls           329

# %%
### 47. Given that the DataFrame is sorted by `points_total`, select the row with the smallest `points_total` using `iloc`

# %%
games.iloc[0]
# Out:
# game_date           2007-10-19 00:00:00
# game_status_text                  Final
# team_id_home                 1610612738
# team_id_away                 1610612751
# points_home                          36
# points_away                          33
# home_team_wins                        1
# team_id_x                    1610612738
# city_home                        Boston
# nickname_home                   Celtics
# team_id_y                    1610612751
# city_away                      Brooklyn
# nickname_away                      Nets
# points_total                         69
# Name: 2475, dtype: object

# %%
games.head()
# Out:
#        game_date game_status_text  team_id_home  team_id_away  points_home  \
# 2475  2007-10-19            Final    1610612738    1610612751           36
# 14885 2003-10-08            Final    1610612754    1610612741           62
# 5948  2004-11-09            Final    1610612751    1610612757           64
# 13807 2005-03-13            Final    1610612765    1610612762           64
# 3555  2003-11-01            Final    1610612750    1610612761           73
#
#        points_away  home_team_wins   team_id_x  city_home nickname_home  \
# 2475            33               1  1610612738     Boston       Celtics
# 14885           58               1  1610612754    Indiana        Pacers
# 5948            60               1  1610612751   Brooklyn          Nets
# 13807           62               1  1610612765    Detroit       Pistons
# 3555            56               1  1610612750  Minnesota  Timberwolves
#
#         team_id_y city_away  nickname_away  points_total
# 2475   1610612751  Brooklyn           Nets            69
# 14885  1610612741   Chicago          Bulls           120
# 5948   1610612757  Portland  Trail Blazers           124
# 13807  1610612762      Utah           Jazz           126
# 3555   1610612761   Toronto        Raptors           129

# %%
### 48. Select the rows with the second, and third smallest `points_total` using `iloc`

# %%
games.iloc[[1,2]]
# Out:
#        game_date game_status_text  team_id_home  team_id_away  points_home  \
# 14885 2003-10-08            Final    1610612754    1610612741           62
# 5948  2004-11-09            Final    1610612751    1610612757           64
#
#        points_away  home_team_wins   team_id_x city_home nickname_home  \
# 14885           58               1  1610612754   Indiana        Pacers
# 5948            60               1  1610612751  Brooklyn          Nets
#
#         team_id_y city_away  nickname_away  points_total
# 14885  1610612741   Chicago          Bulls           120
# 5948   1610612757  Portland  Trail Blazers           124

# %%
### 49. Select a subset including the first 4 rows, and the first 5 columns using `iloc`

# %%
games.iloc[:4,:5]
# Out:
#        game_date game_status_text  team_id_home  team_id_away  points_home
# 2475  2007-10-19            Final    1610612738    1610612751           36
# 14885 2003-10-08            Final    1610612754    1610612741           62
# 5948  2004-11-09            Final    1610612751    1610612757           64
# 13807 2005-03-13            Final    1610612765    1610612762           64
